# %%
import pandas as pd
import numpy as np
from os import remove
from os import path
from numpy import pi, cos, sin, sqrt
from numpy import arccos as acos
import math
import matplotlib.pyplot as plt
from datetime import datetime
import streamlit as st
import altair as alt
from matplotlib import cm
import random 
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource
import requests
import pydeck as pdk
import json

# %%
latitud_f=47.7197
longitud_f=12.8928

url = "https://maps.googleapis.com/maps/api/elevation/json?locations="+str(latitud_f)+","+str(longitud_f)+"&key=AIzaSyDhpSAZtcnr-OvNY1f58WpMMXFG_V1_lSs"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)
results=json.loads(response.text)["results"]
if len(results)==0:
    print("error")
else:    
    elevation_f=int(results[0]['elevation'])

# %%
lat_f=np.radians(latitud_f)
lon_f=np.radians(longitud_f)

del_lat_grad=0.0035
del_lon_grad=0.0035
dis=150
dis_lat=0
dis_lon=0
Rt=6371000
i=0
while not(((dis_lat>dis*0.999)and(dis_lat<dis*1.001)) and ((dis_lon>dis*0.999)and(dis_lon<dis*1.001))):
    
    if dis_lat>dis:
        del_lat_grad-=0.000001
    else:
        del_lat_grad+=0.000001
    if dis_lon>dis:
        del_lon_grad-=0.000001
    else:
        del_lon_grad+=0.000001
    del_lat=np.radians(del_lat_grad)
    del_lon=np.radians(del_lon_grad)
    
    dis_lat=Rt*acos(sin(lat_f)*sin(lat_f+del_lat)+cos(lat_f)*cos(lat_f+del_lat)*cos(0))
    dis_lon=Rt*acos(sin(lat_f)*sin(lat_f)+cos(lat_f)*cos(lat_f)*cos(del_lon))
print("dis_lat",dis_lat)
print("dis_lon",dis_lon)
    

del_lon_grad
# Out:
# dis_lat 150.11315091220592
# dis_lon 150.06343001445993
# 0.0020059999999998018

# %%
num_r=20
fac=10
t=np.power(np.linspace(0.5,fac,num_r),0.5 )
num_ang=20
ang=np.linspace(0,2*pi,num_ang)
r=np.linspace(dis,num_r*dis,num_r)*t
print(t,r)
# Out:
# [0.70710678 1.         1.22474487 1.41421356 1.58113883 1.73205081
#  1.87082869 2.         2.12132034 2.23606798 2.34520788 2.44948974
#  2.54950976 2.64575131 2.73861279 2.82842712 2.91547595 3.
#  3.082207   3.16227766] [ 106.06601718  300.          551.13519213  848.52813742 1185.85412256
#  1558.84572681 1964.37012806 2400.         2863.78246381 3354.10196625
#  3869.59300185 4409.08153701 4971.54402575 5556.07775324 6161.87877193
#  6788.22509939 7434.46366593 8100.         8784.28995423 9486.83298051]

# %%
elev_p=np.array([elevation_f])
dis_lat_p=np.array([0])
dis_lon_p=np.array([0])
lat_p=np.array([latitud_f])
lon_p=np.array([longitud_f])
for ii, r_p in enumerate(r):
 
    for kk in ang:
        lat_ii=latitud_f+(t[ii])*(ii+1)*cos(kk)*del_lat_grad
        lon_kk=longitud_f+(t[ii])*(ii+1)*sin(kk)*del_lon_grad
        dis_lat_ii=r_p*cos(kk)
        dis_lon_kk=r_p*sin(kk)
        
        url = "https://maps.googleapis.com/maps/api/elevation/json?locations="+str(lat_ii)+","+str(lon_kk)+"&key=AIzaSyDhpSAZtcnr-OvNY1f58WpMMXFG_V1_lSs"
        response = requests.request("GET", url, headers=headers, data=payload)
        results=json.loads(response.text)["results"]
        if len(results)==0:
            print("error")
            eleviikk=0
        else:    
            eleviikk=int(results[0]['elevation'])
        dis_lat_p=np.append(dis_lat_p,dis_lat_ii)
        dis_lon_p=np.append(dis_lon_p,dis_lon_kk)
        lat_p=np.append(lat_p,lat_ii)
        lon_p=np.append(lon_p,lon_kk)
        elev_p=np.append(elev_p,eleviikk)

# %%
# %matplotlib notebook
fig, ax = plt.subplots(figsize=(10,6))
plt.title('Jueputa')
ax.plot(dis_lon_p, dis_lat_p)
ax.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
dist=max(r)

ax = plt.figure(figsize=(10,8)).add_subplot(projection='3d')
ax.plot(dis_lon_p, dis_lat_p,elev_p, label='parametric curve')
ax.set_title("Trayectoria de la tierra alrededor del sol")
ax.plot_trisurf(dis_lon_p, dis_lat_p,  elev_p, linewidth=0.2, antialiased=True)
ax.set_xlim(-dist,dist )
ax.set_ylim(-dist,dist)
ax.set_zlim(elevation_f,elevation_f+ (max(elev_p)-elevation_f)*3)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5, 0, 'z')

# %%
dist=max(r)


ax = plt.figure(figsize=(10,8)).add_subplot(projection='3d')
ax.plot(lon_p, lat_p,elev_p, label='parametric curve')
ax.set_title("Trayectoria de la tierra alrededor del sol")
#ax.plot_trisurf(dis_lon_p[vec1:vec2], dis_lat_p[vec1:vec2],  elev_p[vec1:vec2], linewidth=0.2, antialiased=True)
dist2=0.2
ax.set_xlim(-dist2+longitud_f,dist2+longitud_f )
ax.set_ylim(-dist2+latitud_f,dist2+latitud_f)
ax.set_zlim(elevation_f,elevation_f+ dist/9)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5, 0, 'z')

# %%
elev_rel=elev_p-elevation_f-0.01
for i in range(0,len(dis_lat_p[vec1:vec2])):
    print(dis_lon_p[vec1:vec2][i],dis_lat_p[vec1:vec2][i],elev_rel[vec1:vec2][i])
# Out:
# 0.0 0.0 -0.01
# 0.0 106.06601717798213 3.99
# 34.439579478345635 100.3190678054512 4.99
# 65.1470961350773 83.70099082547945 5.99
# 88.79491406422416 58.01261273487902 6.99
# 102.82042525946146 26.037667896021322 8.99
# 105.70374795455606 -8.758862275414916 9.99
# 97.13242939613318 -42.60623381155867 11.99
# 78.03530494770858 -71.83655881038656 10.99
# 50.48184436568607 -93.28227800305184 7.99
# 17.457892640119265 -104.61941495040999 3.99
# -17.45789264011924 -104.61941495041 -0.01
# -50.481844365686044 -93.28227800305186 -3.01
# -78.03530494770852 -71.83655881038662 -5.01
# -97.13242939613315 -42.60623381155873 -5.01
# -105.70374795455606 -8.758862275414966 -3.01
# -102.82042525946147 26.037667896021276 -0.01
# -88.79491406422419 58.012612734878985 1.99
# -65.14709613507733 83.70099082547942 3.99
# -34.439579478345664 100.3190678054512 3.99
# -2.59786816870648e-14 106.06601717798213 3.99
# 0.0 300.0 -5.01
# 97.40984076140504 283.7451725101904 -4.01
# ...

# %%
r_sombra=sqrt(dis_lon_p*dis_lon_p+dis_lat_p*dis_lat_p+(elev_rel)*(elev_rel))
r_sombra
# Out:
# array([1.00000000e-02, 1.06141039e+02, 1.06183332e+02, 1.06235023e+02,
#        1.06296096e+02, 1.06446325e+02, 1.06535441e+02, 1.06741558e+02,
# ...

# %%
zenith_sombra=th_sombra*180/pi
azimut_sombra=np.round(phi_sombra*180/pi,3)
incli_sombra=90-zenith_sombra
#zenith_sombra=zenith_sombra*(zenith_sombra<90)+90*(zenith_sombra>90)

# %%
fig, ax = plt.subplots(figsize=(10,6))
plt.title('Jueputa')
ax.scatter(azimut_sombra, incli_sombra)
ax.grid(True)
ax.set_xlim(-180,180 )
ax.set_ylim(-40,90)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# (-40.0, 90.0)

# %%
cond=azimut_sombra==180

azimut_f=azimut_sombra.copy()
incli_f=incli_sombra.copy()


azimut_new=np.array([min(azimut_f)])
pos1=np.where(azimut_f==azimut_new[0])

incli_new=np.array([max(incli_f[pos1])])

for ii in range(0,len(incli_f)):
    
    try:
        azim_p=max(azimut_new)
        pos=np.where(azimut_f>azim_p)
        
        azim_min=min(azimut_f[pos])
        
        pos1=np.where(azimut_f==azim_min)
        print(pos1)
        azimut_new=np.append(azimut_new,min(azimut_f[pos[0]]))
        incli_new=np.append(incli_new,max(incli_f[pos1[0]]))
    except:
        break
    
incli_new[azimut_new==180]=max(incli_f[np.where(azimut_f==180)])
incli_new[-1]
# Out:
# (array([ 19,  39,  59,  79,  99, 119, 139, 159, 179, 199, 219, 239, 259,
#        279, 299, 319, 339, 359, 379, 399], dtype=int64),)
# (array([ 18,  38,  58,  78,  98, 118, 138, 158, 178, 198, 218, 238, 258,
#        278, 298, 318, 338, 358, 378, 398], dtype=int64),)
# (array([ 17,  37,  57,  77,  97, 117, 137, 157, 177, 197, 217, 237, 257,
#        277, 297, 317, 337, 357, 377, 397], dtype=int64),)
# (array([ 16,  36,  56,  76,  96, 116, 136, 156, 176, 196, 216, 236, 256,
#        276, 296, 316, 336, 356, 376, 396], dtype=int64),)
# (array([ 15,  35,  55,  75,  95, 115, 135, 155, 175, 195, 215, 235, 255,
#        275, 295, 315, 335, 355, 375, 395], dtype=int64),)
# (array([ 14,  34,  54,  74,  94, 114, 134, 154, 174, 194, 214, 234, 254,
#        274, 294, 314, 334, 354, 374, 394], dtype=int64),)
# (array([ 13,  33,  53,  73,  93, 113, 133, 153, 173, 193, 213, 233, 253,
#        273, 293, 313, 333, 353, 373, 393], dtype=int64),)
# ...

# %%
# %matplotlib notebook
fig, ax = plt.subplots(figsize=(10,6))
plt.title('Jueputa')

ax.plot(azimut_new, incli_new)
#ax.scatter(azimut_sombra, incli_sombra)
ax.grid(True)
ax.set_xlim(-180,180 )
ax.set_ylim(-4,90)
azimut_new
# Out:
# <img src="data:image/png;base64,..." width="1000">
# array([-180.   , -161.053, -142.105, -123.158, -104.211,  -85.263,
#         -66.316,  -47.368,  -28.421,   -9.474,    9.474,   28.421,
#          47.368,   66.316,   85.263,  104.211,  123.158,  142.105,
#         161.053,  180.   ])

# %%
df=pd.DataFrame(data={"Azimut_sombra":azimut_new,"Elevacion_sombra":incli_new})

# %%
df.to_csv("Sombra_prueba.csv",index=False)

# %%
df2=pd.DataFrame(data={"Distancia_longitud":dis_lon_p,"Distancia_latitud":dis_lat_p})

# %%
df2.to_csv("Relieve_prueba.csv",index=False)
